# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd
import math

# %%
def computeGCD(x, y):
    while(y):
        x, y = y, x % y
    return x

# %%
def PPT_from_ST(s, t):
    #assumes s>t
    a=float(s*t)
    b=float((s**2 - t**2)/2)
    c=float((s**2 + t**2)/2)
    return a, b, c

# %%
ppts={}
for i in range(1, 100):
    for j in range(i+1, 100):
        a, b, c = PPT_from_ST(j, i)
        #add error checking and remove non int solutions
        if not a in ppts:
            ppts[a]={}
        if b.is_integer(): #a is always an int (technically a float but always a whole number)
            if not b in ppts[a]:
                ppts[a][b]=[]
            if c.is_integer(): #so b and c are the only ones we need to check for whole numberness
                if not c in ppts[a][b]:
                    ppts[a][b].append(c)

# %% [markdown]
# ### now that we have a list of PPTS, we can try and make a dataframe from it
# ### that means we need a list of all the a's (with repeats for multiple b's or c's), b's (with repeats for c's) and c's
# ### first, we should remove any incomplete PPTS in the dict

# %%
#lets remove inocmpletes and build the dataframe at the same time
DF=pd.DataFrame(columns=["A", "B", "C"])#, index=['x', 'y'])
for a, bcs in ppts.items():
    for b, cs in bcs.items():
        for c in cs: #by only adding when theres a C we get rid of any and all imcomletes
            #lets remove triples with common factors to get those Primitive triples we want
            if math.gcd(int(a), int(b))==1 and math.gcd(int(a), int(c))==1 and math.gcd(int(a), int(b))==1:
                DF=DF.append({"A": int(a), "B": int(b), "C": int(c)},ignore_index=True)
print(DF)
# Out:
#          A    B     C
# 0        3    4     5
# 1        5   12    13
# 2        7   24    25
# 3        9   40    41
# 4       11   60    61
# ...    ...  ...   ...
# 998   8835  188  8837
# 999   9021  380  9029
# 1000  9215  192  9217
# 1001  9405  388  9413
# 1002  9603  196  9605
#
# [1003 rows x 3 columns]

# %% [markdown]
# ## now that we have a dataframe of primitive pythagorean triples, we can look at each value a, b, and c, independently and in relation to each other

# %%
plt.plot(DF["A"], DF["B"]) #blue
plt.plot(DF["A"], DF["C"]) #ornage
plt.plot(DF["B"], DF["C"]) #green

# %%
plt.plot(range(1, len(DF["A"])+1), DF["A"])

# %% [markdown]
# ### becuase of the nature of the formula used to generate PPTs. A is always odd, B always even, and C always odd
# ### becuase of this, and the nature of the [s,t] forumlas,  a is not ordered. lets order A and see if it makes a difference

# %%
plt.plot(range(1, len(DF["A"])+1), sorted(DF["A"])) #wow

# %%
print(len(DF["A"]), sorted(DF["A"]))
# Out:
# 1003 [3, 5, 7, 9, 11, 13, 15, 15, 17, 19, 21, 21, 23, 25, 27, 29, 31, 33, 33, 35, 35, 37, 39, 39, 41, 43, 45, 45, 47, 49, 51, 51, 53, 55, 55, 57, 57, 59, 61, 63, 63, 65, 65, 67, 69, 69, 71, 73, 75, 75, 77, 77, 79, 81, 83, 85, 85, 87, 87, 89, 91, 91, 93, 93, 95, 95, 97, 99, 99, 105, 105, 105, 111, 115, 117, 119, 123, 129, 133, 135, 141, 143, 145, 147, 153, 155, 159, 161, 165, 165, 165, 171, 175, 177, 183, 185, 187, 189, 195, 195, 195, 201, 203, 205, 207, 209, 213, 215, 217, 219, 221, 225, 231, 231, 231, 235, 237, 245, 247, 249, 253, 255, 255, 255, 259, 261, 265, 267, 273, 273, 273, 275, 279, 285, 285, 285, 287, 291, 295, 297, 299, 301, 305, 315, 315, 315, 319, 323, 325, 329, 333, 335, 341, 345, 345, 351, 355, 357, 357, 365, 369, 371, 377, 385, 385, 385, 387, 391, 395, 399, 399, 403, 405, 407, 413, 415, 423, 425, 427, 429, 429, 435, 435, 437, 441, 445, 451, 455, 455, 455, 459, 465, 465, 469, 473, 475, 477, 481, 483, 483, 485, 493, 495, 495, 495, 497, 511, 513, 517, 525, 525, 527, 531, 533, 539, 549, 551, 553, 555, 559, 561, 561, 567, 575, 581, 583, 585, 585, 589, 595, 595, 603, 609, 609, 611, 615, 621, 623, 627, 627, 629, 637, 639, 645, 649, 651, 651, 657, 663, 663, 665, 665, 667, 671, 675, 679, 689, 693, 693, 693, 697, 703, 705, 711, 713, 715, 715, 725, 731, 735, 737, 741, 741, 747, 759, 759, 765, 765, 767, 775, 777, 779, 781, 783, 793, 795, 799, 801, 803, 805, 817, 819, 819, 825, 825, 833, 837, 851, 855, 855, 861, 869, 871, 873, 885, 891, 893, 897, 897, 899, 901, 903, 913, 915, 923, 925, 931, 935, 935, 943, 945, 949, 957, 957, 969, 969, 975, 975, 979, 987, 989, 999, 1001, 1001, 1003, 1005, 1007, 1015, 1023, 1023, 1025, 1027, 1035, 1037, 1045, 1045, 1053, 1065, 1067, 1071, 1073, 1075, 1079, 1081, 1085, 1095, 1105, 1105, 1107, 1113, 1121, 1127, 1131, 1131, 1139, 1147, 1155, 1155, 1155, 1157, 1159, 1161, 1173, 1173, 1175, 1185, 1189, 1197, 1207, 1209, 1209, 1219, 1221, 1225, 1235, 1235, 1239, 1241, 1245, 1247, 1261, 1265, 1269, 1271, 1273, 1275, 1275, 1281, 1287, 1295, 1305, 1309, 1311, 1311, 1323, 1325, 1333, 1335, 1343, 1349, 1353, 1357, 1363, 1365, 1365, 1365, 1377, 1387, 1395, 1403, 1407, 1411, 1419, 1421, 1425, 1425, 1431, 1435, 1443, 1449, 1455, 1457, 1463, 1475, 1479, 1479, 1485, 1491, 1495, 1501, 1505, 1513, 1517, 1519, 1525, 1533, 1537, 1539, 1541, 1547, 1551, 1575, 1577, 1581, 1581, 1591, 1593, 1595, 1599, 1615, 1615, 1617, 1633, 1643, 1645, 1647, 1649, 1653, 1653, 1659, 1665, 1675, 1677, 1679, 1683, 1691, 1705, 1711, 1725, 1725, 1729, 1739, 1743, 1749, 1755, 1763, 1767, 1767, 1769, 1771, 1775, 1785, 1785, 1809, 1813, 1817, 1825, 1827, 1829, 1833, 1843, 1845, 1855, 1863, 1869, 1881, 1885, 1887, 1891, 1909, 1911, 1917, 1925, 1927, 1935, 1943, 1947, 1953, 1955, 1961, 1971, 1975, 1995, 1995, 2001, 2001, 2009, 2013, 2015, 2021, 2025, 2035, 2037, 2047, 2059, 2065, 2067, 2075, 2077, 2079, 2091, 2093, 2107, 2109, 2115, 2117, 2133, 2135, 2139, 2139, 2145, 2145, 2173, 2175, 2175, 2183, 2185, 2193, 2201, 2205, 2211, 2225, 2231, 2233, 2241, 2255, 2257, 2263, 2275, 2277, 2279, 2291, 2295, 2301, 2303, 2325, 2325, 2331, 2337, 2343, 2345, 2349, 2365, 2379, 2385, 2387, 2397, 2403, 2405, 2407, 2409, 2415, 2419, 2425, 2449, 2451, 2457, 2465, 2475, 2479, 2485, 2491, 2499, 2501, 2511, 2537, 2553, 2555, 2565, 2573, 2581, 2583, 2585, 2597, 2607, 2613, 2619, 2623, 2627, 2635, 2639, 2655, 2665, 2679, 2695, 2697, 2697, 2701, 2703, 2709, 2739, 2745, 2747, 2755, 2759, 2765, 2769, 2773, 2775, 2793, 2795, 2805, 2805, 2813, 2821, 2829, 2835, 2847, 2849, 2867, 2871, 2881, 2891, 2905, 2911, 2915, 2923, 2937, 2945, 2961, 2967, 2989, 2993, 2997, 3003, 3003, 3007, 3009, 3015, 3021, 3045, 3053, 3055, 3069, 3071, 3075, 3081, 3111, 3115, 3127, 3135, 3135, 3139, 3145, 3149, 3157, 3185, 3195, 3201, 3219, 3225, 3233, 3237, 3239, 3243, 3245, 3255, 3283, 3285, 3293, 3311, 3315, 3315, 3321, 3337, 3339, 3355, 3363, 3367, 3381, 3395, 3397, 3403, 3417, 3431, 3441, 3445, 3465, 3465, 3465, 3471, 3477, 3479, 3483, 3485, 3515, 3525, 3551, 3555, 3567, 3569, 3577, 3589, 3 ...

# %%
print(len(np.unique(DF["A"])))
# Out:
# 892

# %%
#lets look at b
plt.plot(range(1, len(DF["B"])+1), DF["B"])
plt.plot(range(1, len(DF["B"])+1), sorted(DF["B"]))

# %%
print(sorted(DF["B"]))
# Out:
# [4, 8, 12, 12, 16, 20, 20, 24, 24, 28, 28, 32, 36, 36, 40, 40, 44, 44, 48, 48, 52, 52, 56, 56, 60, 60, 60, 60, 64, 68, 68, 72, 72, 76, 76, 80, 80, 84, 84, 84, 84, 88, 88, 92, 92, 96, 96, 100, 100, 104, 104, 108, 108, 112, 112, 116, 116, 120, 120, 120, 120, 124, 124, 128, 132, 132, 132, 132, 136, 136, 140, 140, 140, 140, 144, 144, 148, 148, 152, 152, 156, 156, 156, 156, 160, 160, 164, 164, 168, 168, 168, 168, 172, 172, 176, 176, 180, 180, 180, 180, 184, 184, 188, 188, 192, 192, 196, 196, 200, 204, 204, 204, 208, 212, 216, 220, 220, 220, 224, 228, 228, 228, 232, 236, 240, 240, 240, 244, 248, 252, 252, 252, 260, 260, 260, 264, 264, 264, 268, 272, 276, 276, 276, 280, 280, 280, 284, 288, 292, 296, 300, 300, 300, 304, 308, 308, 308, 312, 312, 312, 316, 320, 324, 328, 332, 336, 336, 336, 340, 340, 340, 344, 348, 348, 348, 352, 356, 360, 360, 360, 364, 364, 364, 368, 372, 372, 372, 376, 380, 380, 380, 384, 388, 392, 396, 396, 400, 408, 408, 408, 416, 420, 420, 420, 420, 420, 420, 424, 432, 440, 440, 440, 444, 444, 448, 456, 456, 456, 460, 460, 464, 468, 468, 472, 476, 476, 480, 480, 480, 488, 492, 492, 496, 504, 504, 504, 516, 516, 520, 520, 520, 528, 528, 528, 532, 532, 536, 540, 540, 544, 552, 552, 552, 560, 560, 560, 564, 564, 568, 572, 572, 576, 580, 580, 584, 588, 592, 600, 600, 608, 612, 612, 616, 616, 616, 620, 620, 624, 624, 632, 636, 640, 644, 644, 648, 656, 660, 660, 660, 660, 660, 664, 672, 672, 680, 680, 680, 684, 684, 688, 696, 696, 700, 700, 704, 708, 712, 720, 720, 720, 728, 728, 728, 732, 736, 740, 740, 744, 744, 748, 748, 752, 756, 756, 760, 760, 760, 780, 780, 780, 780, 780, 784, 792, 792, 800, 804, 812, 812, 816, 816, 820, 820, 828, 828, 832, 836, 836, 840, 840, 840, 840, 840, 848, 852, 860, 860, 864, 868, 868, 876, 880, 880, 880, 884, 884, 888, 896, 900, 900, 912, 912, 920, 920, 924, 924, 924, 924, 924, 928, 936, 936, 940, 940, 944, 948, 952, 952, 960, 976, 980, 984, 988, 988, 992, 996, 1008, 1008, 1008, 1012, 1012, 1020, 1020, 1020, 1020, 1032, 1036, 1036, 1040, 1040, 1044, 1044, 1056, 1056, 1060, 1064, 1064, 1068, 1072, 1080, 1088, 1092, 1092, 1092, 1092, 1092, 1100, 1100, 1104, 1104, 1116, 1116, 1120, 1120, 1128, 1136, 1140, 1140, 1140, 1144, 1144, 1148, 1148, 1152, 1160, 1168, 1176, 1180, 1184, 1188, 1188, 1196, 1196, 1200, 1200, 1204, 1204, 1216, 1220, 1224, 1224, 1232, 1232, 1232, 1240, 1248, 1248, 1260, 1260, 1260, 1260, 1260, 1264, 1272, 1276, 1276, 1288, 1288, 1292, 1292, 1296, 1300, 1300, 1312, 1316, 1320, 1320, 1320, 1320, 1328, 1332, 1332, 1340, 1344, 1360, 1360, 1364, 1364, 1368, 1368, 1376, 1380, 1380, 1380, 1392, 1392, 1400, 1404, 1404, 1408, 1416, 1420, 1424, 1428, 1428, 1428, 1440, 1440, 1456, 1456, 1460, 1464, 1472, 1476, 1476, 1480, 1484, 1488, 1496, 1496, 1504, 1508, 1508, 1512, 1520, 1540, 1540, 1540, 1540, 1548, 1548, 1560, 1560, 1560, 1560, 1564, 1564, 1568, 1580, 1584, 1584, 1596, 1596, 1596, 1600, 1608, 1612, 1612, 1620, 1624, 1628, 1628, 1632, 1632, 1640, 1652, 1656, 1660, 1664, 1672, 1672, 1680, 1680, 1680, 1692, 1696, 1700, 1700, 1704, 1708, 1716, 1716, 1716, 1716, 1720, 1728, 1736, 1740, 1740, 1740, 1748, 1748, 1752, 1760, 1760, 1764, 1768, 1768, 1776, 1780, 1800, 1804, 1804, 1820, 1820, 1820, 1824, 1824, 1836, 1836, 1840, 1848, 1848, 1848, 1848, 1856, 1860, 1860, 1872, 1876, 1880, 1888, 1892, 1892, 1896, 1900, 1900, 1904, 1908, 1920, 1924, 1924, 1932, 1932, 1932, 1952, 1960, 1968, 1972, 1972, 1976, 1976, 1980, 1980, 1984, 1988, 1992, 2016, 2024, 2040, 2040, 2040, 2040, 2044, 2052, 2052, 2064, 2068, 2072, 2080, 2080, 2088, 2100, 2100, 2100, 2108, 2108, 2112, 2120, 2124, 2128, 2132, 2132, 2144, 2156, 2160, 2176, 2184, 2184, 2184, 2196, 2200, 2204, 2204, 2208, 2208, 2212, 2220, 2220, 2232, 2236, 2236, 2240, 2244, 2244, 2244, 2256, 2268, 2272, 2280, 2280, 2280, 2296, 2300, 2300, 2320, 2324, 2332, 2336, 2340, 2340, 2352, 2356, 2356, 2360, 2368, 2376, 2380, 2380, 2380, 2392, 2400, 2400, 2408, 2412, 2432, 2436, 2436, 2440, 2444, 2448, 2460, 2460, 2464, 2480, 2484, 2484, 2496, 2508, 2508, 2508 ...
